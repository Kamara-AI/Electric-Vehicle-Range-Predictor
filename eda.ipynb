# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils import load_and_clean_data, DATA_PATH
#style for better visulizatio aesthetics
sns.set_style("whitegrid")

#load the cleaned data
cleaned_data = load_and_clean_data(DATA_PATH)
print(f"cleaned DataFrame loaded with shape: {cleaned_data.shape}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 4
#       2 import matplotlib.pyplot as plt
#       3 import seaborn as sns
# ----> 4 from utils import load_and_clean_data, DATA_PATH
#       5 #style for better visulizatio aesthetics
#       6 sns.set_style("whitegrid")
#
# ImportError: cannot import name 'load_and_clean_data' from 'utils' (c:\Users\Administrator\Whole project practice\utils.py)
